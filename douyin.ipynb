# %%
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import logging
from urllib.parse import urljoin
from os import makedirs
from os.path import exists
import json
import csv
import pandas as pd
from selenium.common.exceptions import NoSuchElementException

# %%
from selenium import webdriver
import time
driver=webdriver.Chrome()
driver.get('https://www.douyin.com/video/6935365422212517127')
time.sleep(5)
result=[]
for cunt in range(1,2000):    
    try:
        a=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div[1]/div[3]/div/div/div[4]/div['+str(cunt)+']/div/div[2]/p/span/span/span/span/span/span')
        time.sleep(1)
        result.append(a.text)
        print(a.text)
        driver.execute_script('window.scrollBy(0,200)')
    except NoSuchElementException:
        print('miss')
text=pd.DataFrame({'content':result})
text.to_excel('liuyunxi.xlsx')
# Out:
# C:\Users\a1392\AppData\Local\Temp/ipykernel_10072/1385814606.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   a=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div[1]/div[3]/div/div/div[4]/div['+str(cunt)+']/div/div[2]/p/span/span/span/span/span/span')
# 是哪位宝贝这么帅气耀眼？！噢 原来是我们家亚太区色彩代言人
# 罗云熙也是一样的濒危那是不是也需守护呢
# 啊啊啊啊啊你就是鹤仙下凡？
# 你就是中国美色
# 宝贝们快来和我们一起守护濒危动物丹顶鹤，行动在遗憾之前，留住中国美色吧～
# 哥哥你就是中国美色
# 哇啊啊啊啊啊啊太绝了，我的寻鹤少年，已经下单等发货了
# 完美日记每次都太会了，中国美色一语双关啊
# 啊啊啊啊，罗云熙帅帅帅
# 熙熙你这个违规了
# 哇，仙男
# 好像真的违规了
# 我的妈。原来香蜜 是罗云熙。原声啊 这台词功底太厉害了吧
# 你就是那个白鹤少年
# 啊啊啊，大龙大龙
# 你就和丹顶鹤一样啊，又仙又没又稀少
# 他古装就像仙鹤一样美
# 罗云熙只有一个，也是濒危动物啊
# 我需要这个眼影盘
#
# 视听盛宴
# 还是胖点好，哥哥不要太瘦了
# 我只记住了四个字，《中国美色》
# 这是长颈鹿的脖子吗？好美
# 啊啊啊啊啊啊啊啊爱啊啊啊撒撒撒啊撒撒
# 哥你咋这么帅呢
# 声音好好听
# 救命！罗公子也太美了！！
# 美就在你身上
# 太仙了
# 哥哥晚安
# 中国有你我活了
# 啊，我要去买
# 嘶 上头了
#
# 你我心中的男神
# 这个妆好绝啊，罗云熙气质真好
# 好美
# 超帅的罗云熙，希望你星途璀璨
#
# 这广告好美
# 这就是鹤仙吧
# 罗云熙好帅！！！
# 好喜欢
# 维克托配音yyds
# 真历害
# 声音好听
# 哇，好爱好爱
# 罗云熙中国美色
# 啊啊啊啊 你就是中国美色
# 我天
# ...
