# %%
import csv
import pandas as pd
from selenium.common.exceptions import NoSuchElementException
from selenium import webdriver
import time
driver=webdriver.Chrome()
driver.get('https://m.weibo.cn/6020329578/4371417258666176')
driver.add_cookie({'name':'SUB','domain':'.weibo.cn','value':'_2A25PEKLlDeRhGeBO4lEY9SzPyDmIHXVs-s6trDV6PUJbkdCOLUrikW1NRY6ZkgKuWpThLZo3LbBcJvAK5eMmklvC'})
driver.refresh()
time.sleep(5)
result=[]
for cunt in range(1,1000):    
    try:
        a=driver.find_element_by_xpath('/html/body/div/div[1]/div/div[4]/div[2]/div['+str(cunt)+']/div/div/div/div/div[2]/div[1]/div/div/h3')
        time.sleep(1)
        result.append(a.text)
        print(a.text)
        driver.execute_script('window.scrollBy(0,300)')
    except NoSuchElementException:
        print('miss')
text=pd.DataFrame({'content':result})
text.to_excel('赖冠霖.xlsx')
# Out:
# C:\Users\a1392\AppData\Local\Temp/ipykernel_36772/2367964370.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   a=driver.find_element_by_xpath('/html/body/div/div[1]/div/div[4]/div[2]/div['+str(cunt)+']/div/div/div/div/div[2]/div[1]/div/div/h3')
# 他拥有牛奶肌，他是勇敢的逐梦少年！正与品牌所倡导的“努力突破自我 积极探索人生更多可能性 遇见更优秀的自己”相吻合✨与绅士少年赖冠霖@赖冠霖_LAIKUANLIN 一起pick完美日记光感持妆气垫，牛奶肌不再是梦想合作愉快～🎉
# 亲笔签名嘛~
# 牛奶肌不再是梦想
# 是想9:23发微博的吗？@PerfectDiary完美日记 很棒耶
# 亲笔签名画册啊啊啊啊啊啊
# 那那只玩偶呢！
# 色号多做一些啊
# Unlimited beauty，美不设限。@PerfectDiary完美日记 他是三国语言Rap能力者💞 暴风成长的少年绅士💞 感谢PerfectDiary完美日记的选择💞 携手牛奶肌肤的#完美日记底妆代言人#赖冠霖❤️ 期待未来的更多精彩✨ @赖冠霖_LAIKUANLIN
# 恭喜霖霖成为完美底妆代言人！想拥有赖冠霖同款牛奶肌！就get同款底妆吧！
# 牛奶少年赖冠霖@赖冠霖_LAIKUANLIN
# 牛奶皮肤赖冠霖呀@赖冠霖_LAIKUANLIN
# 我们奶罐！
# 感谢@PerfectDiary完美日记 的选择恭喜小霖成为完美日记底妆代言人@赖冠霖_LAIKUANLIN
# 感谢@PerfectDiary完美日记 的选择呀！马上就要去买同款啦！用了牛奶肌气垫 秒变赖冠霖同款牛奶肌@赖冠霖_LAIKUANLIN
# 赖冠霖 lgl lkl#完美日记底妆代言人# 恭喜宝贝@赖冠霖_LAIKUANLIN 成为@PerfectDiary完美日记 底妆代言人 少年绅士 未来可期
# 牛奶皮肤赖冠霖！撒浪嘿呦赖冠霖！
# ...
